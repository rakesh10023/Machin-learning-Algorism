# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# %%
data = pd.read_csv('marksheet.csv')

# %%
data.head()
# Out:
#    id     Name  Gender  Age Section  Science  English  History  Maths
# 0   1  Bronnie  Female   13       C       21       81       62     49
# 1   2   Lemmie    Male   15       B       29       41       17     40
# 2   3    Danya  Female   14       C       12       87       16     96
# 3   4    Denna  Female   14       B       15       53       82     33
# 4   5  Jocelin    Male   14       A       43        6        3     21

# %%
data.shape
# Out:
# (250, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       250 non-null    int64
#  1   Name     250 non-null    object
#  2   Gender   250 non-null    object
#  3   Age      250 non-null    int64
#  4   Section  250 non-null    object
#  5   Science  250 non-null    int64
#  6   English  250 non-null    int64
#  7   History  250 non-null    int64
#  8   Maths    250 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 17.7+ KB

# %%
data.isnull().sum()
# Out:
# id         0
# Name       0
# Gender     0
# Age        0
# Section    0
# Science    0
# English    0
# History    0
# Maths      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#    id     Name  Gender  Age Section  Science  English  History  Maths
# 0   1  Bronnie  Female   13       C       21       81       62     49
# 1   2   Lemmie    Male   15       B       29       41       17     40
# 2   3    Danya  Female   14       C       12       87       16     96
# 3   4    Denna  Female   14       B       15       53       82     33
# 4   5  Jocelin    Male   14       A       43        6        3     21

# %%
sns.histplot(x='Gender',y='Age',data=data,hue=True)
plt.show()

# %%
data.head()
# Out:
#    id     Name  Gender  Age Section  Science  English  History  Maths
# 0   1  Bronnie  Female   13       C       21       81       62     49
# 1   2   Lemmie    Male   15       B       29       41       17     40
# 2   3    Danya  Female   14       C       12       87       16     96
# 3   4    Denna  Female   14       B       15       53       82     33
# 4   5  Jocelin    Male   14       A       43        6        3     21

# %%
data.head()
# Out:
#    id     Name  Gender  Age Section  Science  English  History  Maths
# 0   1  Bronnie  Female   13       C       21       81       62     49
# 1   2   Lemmie    Male   15       B       29       41       17     40
# 2   3    Danya  Female   14       C       12       87       16     96
# 3   4    Denna  Female   14       B       15       53       82     33
# 4   5  Jocelin    Male   14       A       43        6        3     21

# %%
 data['total_marks'] = data['Science'] + data['English'] + data['History'] + data['Maths']

# %%
data.head()
# Out:
#    id  Age Section  Science  English  History  Maths  total_marks
# 0   1   13       C       21       81       62     49          213
# 1   2   15       B       29       41       17     40          127
# 2   3   14       C       12       87       16     96          211
# 3   4   14       B       15       53       82     33          183
# 4   5   14       A       43        6        3     21           73

# %%
sns.histplot(data['total_marks'],kde=True)
plt.grid()
plt.show()

# %%
data.head()
# Out:
#    id  Age Section  Science  English  History  Maths  total_marks
# 0   1   13       C       21       81       62     49          213
# 1   2   15       B       29       41       17     40          127
# 2   3   14       C       12       87       16     96          211
# 3   4   14       B       15       53       82     33          183
# 4   5   14       A       43        6        3     21           73

# %%
data.drop(columns='Name',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 data.drop(columns='Name',axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
data.head()

# %%
data.drop(columns='Gender',axis=1,inplace=True)

# %%
data.head()

# %%
data['Section'].unique()

# %%
def Section_class(x):
    if x == 'A':
        return 1
    elif x == 'B':
        return 2 
    else:
        return 3

# %%
data['Section'] = data['Section'].apply(Section_class)

# %%
data.head()
# Out:
#    id  Age  Section  Science  English  History  Maths  total_marks
# 0   1   13        3       21       81       62     49          213
# 1   2   15        2       29       41       17     40          127
# 2   3   14        3       12       87       16     96          211
# 3   4   14        2       15       53       82     33          183
# 4   5   14        1       43        6        3     21           73

# %%
data.head()
# Out:
#    id  Age  Section  Science  English  History  Maths  total_marks
# 0   1   13        3       21       81       62     49          213
# 1   2   15        2       29       41       17     40          127
# 2   3   14        3       12       87       16     96          211
# 3   4   14        2       15       53       82     33          183
# 4   5   14        1       43        6        3     21           73

# %%
data.dtypes
# Out:
# id             int64
# Age            int64
# Section        int64
# Science        int64
# English        int64
# History        int64
# Maths          int64
# total_marks    int64
# dtype: object

# %%
# female is 1 and meal is o

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,r2_score

# %%
# trian, test split

# %%
X = data.iloc[:,:-1]

# %%
X
# Out:
#       id  Age  Section  Science  English  History  Maths
# 0      1   13        3       21       81       62     49
# 1      2   15        2       29       41       17     40
# 2      3   14        3       12       87       16     96
# 3      4   14        2       15       53       82     33
# 4      5   14        1       43        6        3     21
# ..   ...  ...      ...      ...      ...      ...    ...
# 245  246   13        3       28       15       25     10
# 246  247   13        2        1        4       68     65
# 247  248   15        2       93       48       82     44
# 248  249   14        2       35       73       66     59
# 249  250   15        2       50        8       80     78
#
# [250 rows x 7 columns]

# %%
y = data.iloc[:,-1]

# %%
y
# Out:
# 0      213
# 1      127
# 2      211
# 3      183
# 4       73
#       ...
# 245     78
# 246    138
# 247    267
# 248    233
# 249    216
# Name: total_marks, Length: 250, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=50)

# %%
X_train.shape
# Out:
# (200, 7)

# %%
X_test.shape
# Out:
# (50, 7)

# %%
y_train.shape
# Out:
# (200,)

# %%
y_test.shape
# Out:
# (50,)

# %%
data.head()
# Out:
#    id  Age  Section  Science  English  History  Maths  total_marks
# 0   1   13        3       21       81       62     49          213
# 1   2   15        2       29       41       17     40          127
# 2   3   14        3       12       87       16     96          211
# 3   4   14        2       15       53       82     33          183
# 4   5   14        1       43        6        3     21           73

# %%
# Fuchar sckiling

# %%
scalr = StandardScaler()

# %%
X_train_Scaled = scalr.fit_transform(X_train)

# %%
X_train_Scaled
# Out:
# array([[-0.78745121, -0.08583305, -0.09747404, ...,  0.79766207,
#         -0.62618185, -0.21976842],
#        [ 0.24976061,  1.14035343, -1.31589948, ...,  0.19841677,
#         -0.73743714,  0.58270549],
#        [-1.63105016,  1.14035343, -1.31589948, ..., -1.03336522,
#         -1.1082881 , -0.14681625],
#        ...,
#        [ 0.18061315, -1.31201954, -0.09747404, ...,  0.59791364,
#          1.41349845, -1.78824015],
#        [ 1.35611988, -1.31201954,  1.12095141, ..., -1.23311365,
#          1.11681768,  1.45813157],
#        [ 0.69230432, -1.31201954, -0.09747404, ..., -0.36753711,
#          0.26386046, -0.18329234]])

# %%
X_test_Scaled = scalr.transform(X_test)

# %%
X_test_Scaled
# Out:
# array([[ 0.33273755, -1.31201954, -1.31589948,  1.400763  ,  1.6632386 ,
#          0.37511575,  0.58270549],
#        [-1.52041423, -1.31201954, -1.31589948,  1.36652289, -0.06791447,
#         -0.29241598, -0.2927206 ],
#        [-0.26193056, -0.08583305, -0.09747404,  0.16811895,  0.93082769,
#         -1.73873474, -0.47510103],
#        [-1.46509627, -1.31201954, -1.31589948,  0.8529212 ,  1.6299472 ,
#          0.56054123, -1.31405102],
#        [-0.52469089,  1.14035343, -1.31589948,  0.23659918, -1.03336522,
#          0.44928594,  0.50975331],
#        [ 0.58166839, -0.08583305,  1.12095141,  1.50348334,  0.29829099,
#         -1.77581984,  1.71346417],
#        [-0.08214718, -1.31201954, -1.31589948,  0.95564154,  1.36361596,
#          1.63600902,  1.45813157],
#        [-0.67681529,  1.14035343, -0.09747404,  1.22956244, -0.06791447,
#          0.78305181, -0.18329234],
#        [-1.20233594, -1.31201954, -0.09747404,  1.67468391,  0.16512537,
# ...

# %%
# Mobal bulding

# %%
mobal = LinearRegression()

# %%
mobal.fit(X_train_Scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred = mobal.predict(X_test_Scaled)

# %%
y_pred
# Out:
# array([320., 225., 176., 256., 205., 255., 356., 253., 317., 274., 180.,
#        158., 216., 255., 138., 184.,  92., 216., 294., 140., 290., 128.,
#        170., 154., 138., 237., 127., 286., 244., 242., 203., 189., 219.,
#        207., 305., 184., 230., 168., 157., 272., 131., 236., 192., 192.,
#        185., 268., 139., 150., 188., 228.])

# %%
# Model Performance

# %%
sns = mean_squared_error(y_test,y_pred) # cost funchina

# %%
sns
# Out:
# 1.2157293182542056e-27

# %%
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 1.0

# %%
plt.scatter(y_test,y_pred,alpha=0.5)
plt.xlabel(')
