# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/prasertcbs/basic-dataset/refs/heads/master/Loan-Approval-Prediction.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df.fillna(df['Gender'].mode()[0])
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0               5849                0.0       Male            360.0
# 1               4583             1508.0      128.0            360.0
# 2               3000                0.0       66.0            360.0
# 3               2583             2358.0      120.0            360.0
# 4               6000                0.0      141.0            360.0
# ..               ...                ...        ...              ...
# 609             2900                0.0       71.0            360.0
# 610             4106                0.0       40.0            180.0
# 611             8072              240.0      253.0            360.0
# 612             7583                0.0      187.0            360.0
# 613             4583                0.0      133.0            360.0
#
#     Credit_History Property_Area Loan_Status
# 0              1.0         Urban           Y
# 1              1.0         Rural           N
# 2              1.0         Urban           Y
# 3              1.0         Urban           Y
# 4              1.0         Urban           Y
# ..             ...           ...         ...
# 609            1.0         Rural           Y
# 610            1.0         Rural           Y
# 611            1.0         Urban           Y
# 612            1.0         Urban           Y
# 613            0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df['Gender'].fillna('Male')
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# 1              False              False       False             False
# 2              False              False       False             False
# 3              False              False       False             False
# 4              False              False       False             False
# ..               ...                ...         ...               ...
# 609            False              False       False             False
# 610            False              False       False             False
# 611            False              False       False             False
# 612            False              False       False             False
# 613            False              False       False             False
#
#      Credit_History  Property_Area  Loan_Status
# 0             False          False        False
# 1             False          False        False
# 2             False          False        False
# 3             False          False        False
# 4             False          False        False
# ..              ...            ...          ...
# 609           False          False        False
# 610           False          False        False
# 611           False          False        False
# 612           False          False        False
# 613           False          False        False
#
# [614 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Married'].mode()
# Out:
# 0    Yes
# Name: Married, dtype: object

# %%
df['Married'].fillna('Yes', inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14440\2096638298.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Married'].fillna('Yes', inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df['Gender'].fillna('Male', inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14440\2776104287.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna('Male', inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Dependents'].mode()
# Out:
# 0    0
# Name: Dependents, dtype: object

# %%
df['Dependents'].fillna('0', inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14440\4287590747.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Dependents'].fillna('0', inplace=True)

# %%
df['Self_Employed'].mode()
# Out:
# 0    No
# Name: Self_Employed, dtype: object

# %%
df['Self_Employed'].fillna('No', inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14440\372047051.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Self_Employed'].fillna('No', inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Loan_Amount_Term'].mode()
# Out:
# 0    360.0
# Name: Loan_Amount_Term, dtype: float64

# %%
df['Loan_Amount_Term'].fillna('360', inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14440\587655400.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Loan_Amount_Term'].fillna('360', inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_14440\587655400.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '360' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Loan_Amount_Term'].fillna('360', inplace=True)

# %%
df['Credit_History'].mode()
# Out:
# 0    1.0
# Name: Credit_History, dtype: float64

# %%
df['Loan_Amount_Term'].fillna('360', inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Credit_History'].mode()
# Out:
# 0    1.0
# Name: Credit_History, dtype: float64

# %%
df['Credit_History'].fillna('0', inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14440\3541718316.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Credit_History'].fillna('0', inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_14440\3541718316.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Credit_History'].fillna('0', inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount Loan_Amount_Term  \
# 0             5849                0.0         NaN            360.0
# 1             4583             1508.0       128.0            360.0
# 2             3000                0.0        66.0            360.0
# 3             2583             2358.0       120.0            360.0
# 4             6000                0.0       141.0            360.0
#
#   Credit_History Property_Area Loan_Status
# 0            1.0         Urban           Y
# 1            1.0         Rural           N
# 2            1.0         Urban           Y
# 3            1.0         Urban           Y
# 4            1.0         Urban           Y

# %%
df['LoanAmount'].mean()
# Out:
# 146.41216216216216

# %%
df['LoanAmount'].fillna('145', inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14440\3635284368.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LoanAmount'].fillna('145', inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_14440\3635284368.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '145' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['LoanAmount'].fillna('145', inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
def gender_class(x):
    if x == 'Male':
        return 1
    else:
        return 0

# %%
df['Gender'].apply(gender_class)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 609    0
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Gender, Length: 614, dtype: int64

# %%
df['Gender'] = df['Gender'].apply(gender_class)

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001002       1      No          0      Graduate            No
# 1  LP001003       1     Yes          1      Graduate            No
# 2  LP001005       1     Yes          0      Graduate           Yes
# 3  LP001006       1     Yes          0  Not Graduate            No
# 4  LP001008       1      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0             5849                0.0        145            360.0
# 1             4583             1508.0      128.0            360.0
# 2             3000                0.0       66.0            360.0
# 3             2583             2358.0      120.0            360.0
# 4             6000                0.0      141.0            360.0
#
#   Credit_History Property_Area Loan_Status
# 0            1.0         Urban           Y
# 1            1.0         Rural           N
# 2            1.0         Urban           Y
# 3            1.0         Urban           Y
# 4            1.0         Urban           Y

# %%
df['Married'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
def married_class(x):
    if x == 'Yes':
        return 1
    else:
        return 0

# %%
df['Married'].apply(married_class)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 609    0
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Married, Length: 614, dtype: int64

# %%
df['Married'] = df['Married'].apply(married_class)

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married Dependents     Education Self_Employed  \
# 0  LP001002       1        0          0      Graduate            No
# 1  LP001003       1        1          1      Graduate            No
# 2  LP001005       1        1          0      Graduate           Yes
# 3  LP001006       1        1          0  Not Graduate            No
# 4  LP001008       1        0          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0             5849                0.0        145            360.0
# 1             4583             1508.0      128.0            360.0
# 2             3000                0.0       66.0            360.0
# 3             2583             2358.0      120.0            360.0
# 4             6000                0.0      141.0            360.0
#
#   Credit_History Property_Area Loan_Status
# 0            1.0         Urban           Y
# 1            1.0         Rural           N
# 2            1.0         Urban           Y
# 3            1.0         Urban           Y
# 4            1.0         Urban           Y

# %%
def education_class(x):
    if x == 'Graduate':
        return 1
    else:
        return 0

# %%
df['Education'].apply(education_class)
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    1
# Name: Education, Length: 614, dtype: int64

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married Dependents     Education Self_Employed  \
# 0  LP001002       1        0          0      Graduate            No
# 1  LP001003       1        1          1      Graduate            No
# 2  LP001005       1        1          0      Graduate           Yes
# 3  LP001006       1        1          0  Not Graduate            No
# 4  LP001008       1        0          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0             5849                0.0        145            360.0
# 1             4583             1508.0      128.0            360.0
# 2             3000                0.0       66.0            360.0
# 3             2583             2358.0      120.0            360.0
# 4             6000                0.0      141.0            360.0
#
#   Credit_History Property_Area Loan_Status
# 0            1.0         Urban           Y
# 1            1.0         Rural           N
# 2            1.0         Urban           Y
# 3            1.0         Urban           Y
# 4            1.0         Urban           Y

# %%
df['Education'] = df['Education'].apply(education_class)

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education Self_Employed  \
# 0  LP001002       1        0          0          1            No
# 1  LP001003       1        1          1          1            No
# 2  LP001005       1        1          0          1           Yes
# 3  LP001006       1        1          0          0            No
# 4  LP001008       1        0          0          1            No
#
#    ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0             5849                0.0        145            360.0
# 1             4583             1508.0      128.0            360.0
# 2             3000                0.0       66.0            360.0
# 3             2583             2358.0      120.0            360.0
# 4             6000                0.0      141.0            360.0
#
#   Credit_History Property_Area Loan_Status
# 0            1.0         Urban           Y
# 1            1.0         Rural           N
# 2            1.0         Urban           Y
# 3            1.0         Urban           Y
# 4            1.0         Urban           Y

# %%
def self_emplooyed_calss(x):
    if x == 'Yes':
        return 1
    else:
        return 0

# %%
df['Self_Employed'].apply(self_emplooyed_calss)
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 609    0
# 610    0
# 611    0
# 612    0
# 613    1
# Name: Self_Employed, Length: 614, dtype: int64

# %%
df['Self_Employed'] = df['Self_Employed'].apply(self_emplooyed_calss)

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0  LP001002       1        0          0          1              0
# 1  LP001003       1        1          1          1              0
# 2  LP001005       1        1          0          1              1
# 3  LP001006       1        1          0          0              0
# 4  LP001008       1        0          0          1              0
#
#    ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0             5849                0.0        145            360.0
# 1             4583             1508.0      128.0            360.0
# 2             3000                0.0       66.0            360.0
# 3             2583             2358.0      120.0            360.0
# 4             6000                0.0      141.0            360.0
#
#   Credit_History Property_Area Loan_Status
# 0            1.0         Urban           Y
# 1            1.0         Rural           N
# 2            1.0         Urban           Y
# 3            1.0         Urban           Y
# 4            1.0         Urban           Y

# %%
df['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
def property_area_class(x):
    if x == 'Urban':
        return 1
    elif x == 'Rural':
        return 2
    else: 
        return 3

# %%
df['Property_Area'].apply(property_area_class)
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      1
#       ..
# 609    2
# 610    2
# 611    1
# 612    1
# 613    3
# Name: Property_Area, Length: 614, dtype: int64

# %%
df['Property_Area'] = df['Property_Area'].apply(property_area_class)

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0  LP001002       1        0          0          1              0
# 1  LP001003       1        1          1          1              0
# 2  LP001005       1        1          0          1              1
# 3  LP001006       1        1          0          0              0
# 4  LP001008       1        0          0          1              0
#
#    ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0             5849                0.0        145            360.0
# 1             4583             1508.0      128.0            360.0
# 2             3000                0.0       66.0            360.0
# 3             2583             2358.0      120.0            360.0
# 4             6000                0.0      141.0            360.0
#
#   Credit_History  Property_Area Loan_Status
# 0            1.0              1           Y
# 1            1.0              2           N
# 2            1.0              1           Y
# 3            1.0              1           Y
# 4            1.0              1           Y

# %%
sns.countplot(data=df,x='Loan_Status',hue='Education')
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(data=df,x = 'Loan_Status',hue='Self_Employed')
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
df.drop(columns=['Loan_ID'], index=1, inplace=True)

# %%
df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          1              0             5849
# 2       1        1          0          1              1             3000
# 3       1        1          0          0              0             2583
# 4       1        0          0          1              0             6000
# 5       1        1          2          1              1             5417
#
#    CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History  \
# 0                0.0        145            360.0            1.0
# 2                0.0       66.0            360.0            1.0
# 3             2358.0      120.0            360.0            1.0
# 4                0.0      141.0            360.0            1.0
# 5             4196.0      267.0            360.0            1.0
#
#    Property_Area Loan_Status
# 0              1           Y
# 2              1           Y
# 3              1           Y
# 4              1           Y
# 5              1           Y

# %%
df['Dependents'].unique()
# Out:
# array(['0', '2', '3+', '1'], dtype=object)

# %%
def dep(x):
    if x == '3+':
        return 3
    elif x == '0':
        return 0
    elif x == '2':
        return 2
    else:
        return 1

# %%
df['Dependents'].apply(dep)
# Out:
# 0      0
# 2      0
# 3      0
# 4      0
# 5      2
#       ..
# 609    0
# 610    3
# 611    1
# 612    2
# 613    0
# Name: Dependents, Length: 613, dtype: int64

# %%
df['Dependents'] = df['Dependents'].apply(dep)

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          1              0             5849
# 2       1        1           0          1              1             3000
# 3       1        1           0          0              0             2583
# 4       1        0           0          1              0             6000
# 5       1        1           2          1              1             5417
#
#    CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History  \
# 0                0.0        145            360.0            1.0
# 2                0.0       66.0            360.0            1.0
# 3             2358.0      120.0            360.0            1.0
# 4                0.0      141.0            360.0            1.0
# 5             4196.0      267.0            360.0            1.0
#
#    Property_Area Loan_Status
# 0              1           Y
# 2              1           Y
# 3              1           Y
# 4              1           Y
# 5              1           Y

# %%
def loan_status(x):
    if x == 'Y':
        return 1
    else:
        return 0

# %%
df['Loan_Status'].apply(loan_status)
# Out:
# 0      1
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 613, dtype: int64

# %%
df['Loan_Status'] = df['Loan_Status'].apply(loan_status)

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          1              0             5849
# 2       1        1           0          1              1             3000
# 3       1        1           0          0              0             2583
# 4       1        0           0          1              0             6000
# 5       1        1           2          1              1             5417
#
#    CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History  \
# 0                0.0        145            360.0            1.0
# 2                0.0       66.0            360.0            1.0
# 3             2358.0      120.0            360.0            1.0
# 4                0.0      141.0            360.0            1.0
# 5             4196.0      267.0            360.0            1.0
#
#    Property_Area  Loan_Status
# 0              1            1
# 2              1            1
# 3              1            1
# 4              1            1
# 5              1            1

# %%
import matplotlib as plt

# %%
sns.heatmap(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[331], line 1
# ----> 1 sns.heatmap(df)
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:306, in _HeatMapper.plot(self, ax, cax, kws)
#     303     kws.setdefault("vmax", self.vmax)
#     305 # Draw the heatmap
# --> 306 mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
#     308 # Set the axis limits
#     309 ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:6434, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6430 coords = np.stack([X, Y], axis=-1)
#    6432 kwargs.setdefault('snap', mpl.rcParams['pcolormesh.snap'])
# -> 6434 collection = mcoll.QuadMesh(
#    6435     coords, antialiased=antialiased, shading=shading,
#    6436     array=C, cmap=cmap, norm=norm, alpha=alpha, **kwargs)
#    6437 collection._scale_norm(norm, vmin, vmax)
#    6439 coords = coords.reshape(-1, 2)  # flatten the grid structure; keep x, y
#
# File ~\anaconda3\Lib\site-packages\matplotlib\collections.py:2146, in QuadMesh.__init__(self, coordinates, antialiased, shading, **kwargs)
#    2144 kwargs.setdefault("pickradius", 0)
#    2145 super().__init__(coordinates=coordinates, shading=shading)
# -> 2146 Collection.__init__(self, **kwargs)
#    2148 self._antialiased = antialiased
#    2149 self._bbox = transforms.Bbox.unit()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\collections.py:206, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, offset_transform, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     203 self._offset_transform = offset_transform
#     205 self._path_effects = None
# --> 206 self._internal_update(kwargs)
#     207 self._paths = None
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1192, in Artist._update_props(self, props, errfmt)
#    1189             if not callable(func):
#    1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
# -> 1192             ret.append(func(v))
#    1193 if ret:
#    1194     self.pchanged()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\collections.py:2020, in _MeshData.set_array(self, A)
#    2015     if shape not in ok_shapes:
#    2016         raise ValueError(
#    2017             f"For X ({width}) and Y ({height}) with {self._shading} "
#    2018             f"shading, A should have shape "
#    2019             f"{' or '.join(map(str, ok_shapes))}, not {A.shape}")
# -> 2020 return super().set_array(A)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\cm.py:452, in ScalarMappable.set_array(self, A)
#     450 A = cbook.safe_masked_invalid(A, copy=True)
#     451 if not np.can_cast(A.dtype, float, "same_kind"):
# --> 452     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     453                     "converted to float")
#     455 self._A = A
#     456 if not self.norm.scaled():
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
df.corr()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Devide data

# %%
X = df.iloc[:,:-1]

# %%
X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          1              0             5849
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# 5         1        1           2          1              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           3          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
#      CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History  \
# 0                  0.0        145            360.0            1.0
# 2                  0.0       66.0            360.0            1.0
# 3               2358.0      120.0            360.0            1.0
# 4                  0.0      141.0            360.0            1.0
# 5               4196.0      267.0            360.0            1.0
# ..                 ...        ...              ...            ...
# 609                0.0       71.0            360.0            1.0
# 610                0.0       40.0            180.0            1.0
# 611              240.0      253.0            360.0            1.0
# 612                0.0      187.0            360.0            1.0
# 613                0.0      133.0            360.0            0.0
#
#      Property_Area
# 0                1
# 2                1
# 3                1
# 4                1
# 5                1
# ..             ...
# 609              2
# 610              2
# 611              1
# 612              1
# 613              3
#
# [610 rows x 11 columns]

# %%
y = df.iloc[:,  -1]

# %%
y
# Out:
# 0      1
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 610, dtype: int64

# %% [markdown]
# # split data

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=49)

# %%
scalar = StandardScaler()

# %%
X_train = scalar.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.4819992 , -1.36154367, -0.73578881, ..., -4.33546332,
#          0.54261377, -1.22443146],
#        [ 0.4819992 ,  0.73446047, -0.73578881, ...,  0.27995138,
#         -1.84293147,  1.16565875],
#        [ 0.4819992 ,  0.73446047, -0.73578881, ...,  0.27995138,
#          0.54261377, -1.22443146],
#        ...,
#        [ 0.4819992 ,  0.73446047,  1.29857345, ...,  0.27995138,
#          0.54261377, -0.02938635],
#        [ 0.4819992 ,  0.73446047, -0.73578881, ...,  0.27995138,
#          0.54261377, -0.02938635],
#        [ 0.4819992 ,  0.73446047,  1.29857345, ...,  0.27995138,
#          0.54261377,  1.16565875]])

# %%
X_test = scalar.transform(X_test)

# %% [markdown]
# # bulid model

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #  Testing

# %%
y_pred= model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7950819672131147

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.55      0.58        31
#            1       0.85      0.88      0.86        91
#
#     accuracy                           0.80       122
#    macro avg       0.73      0.71      0.72       122
# weighted avg       0.79      0.80      0.79       122
